# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
### 2. Define root directory ###

ROOT_DIR = '/content/gdrive/My Drive/ColabNotebooks/new_model_with_warp_smaller/CRV.v6i.yolov8'

# %%
### 3. Install Ultralytics ###

# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 16.2 MB/s eta 0:00:00
# ...

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n.pt")  # load pre trained model

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=180, batch=32)
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
import os

# Define source and destination paths
source_path = "/content/runs"
destination_path = "/content/gdrive/My Drive/ColabNotebooks/Results"

# Ensure destination directory exists
os.makedirs(destination_path, exist_ok=True)

# Copy results to Google Drive
shutil.copytree(source_path, destination_path, dirs_exist_ok=True)

print(f"Results copied to: {destination_path}")
# Out:
# Results copied to: /content/gdrive/My Drive/ColabNotebooks/Results

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import os

# Path to the trained model (stored locally in Colab)
model_path = '/content/gdrive/My Drive/ColabNotebooks/Results/detect/train2/weights/best.pt'  # Update this path if necessary

# Load the trained model
model = YOLO(model_path)
print("Model classes:", model.names)

# Path to the image or video you want to use for predictions
image_path = '/content/gdrive/My Drive/ColabNotebooks/Test.jpg'  # Replace with your input file's path

# Define the custom folder to save results
result_folder = '/content/gdrive/MyDrive/ColabNotebooks/Results/predict/runs/detect/predict'

# Create the folder if it doesn't exist
os.makedirs(result_folder, exist_ok=True)

# Set the threshold for predictions
threshold = 10  # Not directly used, but you can adjust confidence as needed in conf parameter

# Perform prediction with the specified confidence threshold and save in the custom folder
results = model.predict(source=image_path, save=True, conf=0.71, save_dir=result_folder)

# Display a message indicating the location of the saved results
print(f"Results saved in folder: {result_folder}")
# Out:
# Model classes: {0: 'Speed Limit -10-', 1: 'Speed Limit -100-', 2: 'Speed Limit -110-', 3: 'Speed Limit -120-', 4: 'Speed Limit -20-', 5: 'Speed Limit -30-', 6: 'Speed Limit -40-', 7: 'Speed Limit -50-', 8: 'Speed Limit -60-', 9: 'Speed Limit -70-', 10: 'Speed Limit -80-', 11: 'Speed Limit -90-'}
#
# image 1/1 /content/gdrive/My Drive/ColabNotebooks/Test.jpg: 480x640 1 Speed Limit -30-, 175.9ms
# Speed: 2.7ms preprocess, 175.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict3
# Results saved in folder: /content/gdrive/MyDrive/ColabNotebooks/Results/predict/runs/detect/predict

# %%
from ultralytics import YOLO
import os

# Path to the trained model (stored locally in Colab)
model_path = '/content/gdrive/My Drive/ColabNotebooks/Results/detect/train2/weights/best.pt'  # Update this path if necessary

# Load the trained model
model = YOLO(model_path)
print("Model classes:", model.names)

# Define the class to exclude (by name or index)
class_to_exclude = "Speed Limit -100-"  # Replace "class_name" with the name of the class to exclude
class_to_exclude_index = next((index for index, name in model.names.items() if name == class_to_exclude), None)

if class_to_exclude_index is None:
    raise ValueError(f"Class '{class_to_exclude}' not found in the model's class list.")

# Create a list of all class indices except the one to exclude
classes_to_include = [index for index in model.names.keys() if index != class_to_exclude_index]

# Path to the image or video you want to use for predictions
image_path = '/content/gdrive/My Drive/ColabNotebooks/Test11.mp4'  # Replace with your input file's path

# Define the custom folder to save results
result_folder = '/content/gdrive/MyDrive/ColabNotebooks/Results/predict/runs/detect/predict'

# Create the folder if it doesn't exist
os.makedirs(result_folder, exist_ok=True)

# Set the threshold for predictions
confidence_threshold = 0.71

# Perform prediction, excluding the specified class
results = model.predict(
    source=image_path,
    save=True,
    conf=confidence_threshold,
    save_dir=result_folder,
    classes=classes_to_include
)

# Display a message indicating the location of the saved results
print(f"Results saved in folder: {result_folder}")
# Out:
# Model classes: {0: 'Speed Limit -10-', 1: 'Speed Limit -100-', 2: 'Speed Limit -110-', 3: 'Speed Limit -120-', 4: 'Speed Limit -20-', 5: 'Speed Limit -30-', 6: 'Speed Limit -40-', 7: 'Speed Limit -50-', 8: 'Speed Limit -60-', 9: 'Speed Limit -70-', 10: 'Speed Limit -80-', 11: 'Speed Limit -90-'}
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/60) /content/gdrive/My Drive/ColabNotebooks/Test11.mp4: 384x640 (no detections), 142.8ms
# ...

# %%
from ultralytics import YOLO
import os

# Path to the trained model (stored locally in Colab)
model_path = '/content/gdrive/My Drive/ColabNotebooks/Results/detect/train2/weights/best.pt'  # Update this path if necessary

# Load the trained model
model = YOLO(model_path)
print("Model classes:", model.names)

# Define the classes to exclude (by name or index)
classes_to_exclude = ["Speed Limit -100-", "Speed Limit -60-"]  # Replace with the names of the classes to exclude

# Find indices for the classes to exclude
indices_to_exclude = [
    index for index, name in model.names.items() if name in classes_to_exclude
]

if not indices_to_exclude:
    raise ValueError(f"Classes '{classes_to_exclude}' not found in the model's class list.")

# Create a list of all class indices except the ones to exclude
classes_to_include = [
    index for index in model.names.keys() if index not in indices_to_exclude
]

# Path to the image or video you want to use for predictions
image_path = '/content/gdrive/My Drive/ColabNotebooks/Untitleddesign.mp4'  # Replace with your input file's path

# Define the custom folder to save results
result_folder = '/content/gdrive/MyDrive/ColabNotebooks/Results/predict/runs/detect/predict'

# Create the folder if it doesn't exist
os.makedirs(result_folder, exist_ok=True)

# Set the threshold for predictions
confidence_threshold = 0.01

# Perform prediction, excluding the specified classes
results = model.predict(
    source=image_path,
    save=True,
    conf=confidence_threshold,
    save_dir=result_folder,
    classes=classes_to_include
)

# Display a message indicating the location of the saved results
print(f"Results saved in folder: {result_folder}")
# Out:
# Model classes: {0: 'Speed Limit -10-', 1: 'Speed Limit -100-', 2: 'Speed Limit -110-', 3: 'Speed Limit -120-', 4: 'Speed Limit -20-', 5: 'Speed Limit -30-', 6: 'Speed Limit -40-', 7: 'Speed Limit -50-', 8: 'Speed Limit -60-', 9: 'Speed Limit -70-', 10: 'Speed Limit -80-', 11: 'Speed Limit -90-'}
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/19) /content/gdrive/My Drive/ColabNotebooks/Untitleddesign.mp4: 384x640 (no detections), 131.6ms
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score
from ultralytics import YOLO
import os

# Path to the trained model
model_path = '/content/gdrive/My Drive/ColabNotebooks/Results/detect/train2/weights/best.pt'

# Load the trained model
model = YOLO(model_path)
print("Model classes:", model.names)

# Path to the image for predictions
image_path = '/content/gdrive/My Drive/ColabNotebooks/Test.jpg'

# Custom folder to save results
result_folder = '/content/gdrive/MyDrive/ColabNotebooks/Results/predict/runs/detect/predict'
os.makedirs(result_folder, exist_ok=True)

# Define thresholds to test
thresholds = np.linspace(0.1, 1.0, 10)  # Thresholds from 0.1 to 1.0

# Placeholder for precision-recall values
all_precisions = []
all_recalls = []
average_precisions = []

# Ground truth labels for testing (update with your actual dataset)
# Replace with the actual binary ground truth labels for evaluation
# For example: [1 if object is present else 0 for all images]
y_true = [1, 0, 1, 1, 0]  # Example ground truth (binary labels)

for conf in thresholds:
    print(f"Running prediction with confidence threshold: {conf:.2f}")

    # Perform predictions
    results = model.predict(source=image_path, save=True, conf=conf, save_dir=result_folder)

    # Debugging: Check predictions
    y_scores = []  # Predicted confidence scores
    for result in results:
        if len(result.boxes) == 0:
            print(f"No predictions found for threshold {conf:.2f}")
        for pred in result.boxes:
            y_scores.append(pred.conf.item())  # Convert tensor to Python float
            print(f"Predicted Class: {int(pred.cls.item())}, Confidence: {pred.conf.item():.2f}, Coordinates: {pred.xyxy.tolist()}")

    if not y_scores:
        print(f"No detections for threshold {conf:.2f}")
        all_precisions.append([0])
        all_recalls.append([0])
        average_precisions.append(0)
        continue

    # Calculate precision, recall, and average precision
    precision, recall, _ = precision_recall_curve(y_true[:len(y_scores)], y_scores)
    all_precisions.append(precision)
    all_recalls.append(recall)
    average_precisions.append(average_precision_score(y_true[:len(y_scores)], y_scores))

# Plot Precision-Recall curves
plt.figure(figsize=(10, 8))
for i, conf in enumerate(thresholds):
    if len(all_precisions[i]) > 1:  # Skip thresholds with no detections
        plt.plot(all_recalls[i], all_precisions[i], label=f'Threshold: {conf:.2f} (AP={average_precisions[i]:.2f})')

plt.title('Precision-Recall Curves at Different Thresholds')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Model classes: {0: 'Speed Limit -10-', 1: 'Speed Limit -100-', 2: 'Speed Limit -110-', 3: 'Speed Limit -120-', 4: 'Speed Limit -20-', 5: 'Speed Limit -30-', 6: 'Speed Limit -40-', 7: 'Speed Limit -50-', 8: 'Speed Limit -60-', 9: 'Speed Limit -70-', 10: 'Speed Limit -80-', 11: 'Speed Limit -90-'}
# Running prediction with confidence threshold: 0.10
#
# image 1/1 /content/gdrive/My Drive/ColabNotebooks/Test.jpg: 480x640 1 Speed Limit -30-, 705.2ms
# Speed: 8.8ms preprocess, 705.2ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict9
# Predicted Class: 5, Confidence: 0.95, Coordinates: [[162.69573974609375, 101.32582092285156, 321.6195068359375, 261.33734130859375]]
# Running prediction with confidence threshold: 0.20
#
# image 1/1 /content/gdrive/My Drive/ColabNotebooks/Test.jpg: 480x640 1 Speed Limit -30-, 427.8ms
# Speed: 3.9ms preprocess, 427.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# ...
